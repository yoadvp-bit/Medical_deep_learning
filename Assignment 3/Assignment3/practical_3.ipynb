# %%
from google.colab import drive

mount = "/content/gdrive/"
drive.mount(mount)

dir = "/content/gdrive/MyDrive/DL_4_MI/Assignment3"
# !cd $dir
# !ls # Verify that FastMRIdata and train_VarNet.py are there
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# dataset_cache.pkl      FastMRIdata		    save_model		   train_VarNet.py
# evaluation_metrics.py  __pycache__		    test_VarNet_answer.py  varnet
# fastmri		       reconstruction_functions.py  test_VarNet.py	   wandb

# %%
# !pip install fastmri==0.3.0
# !pip install matplotlib==3.10.1
# !pip install wandb==0.19.8
# !pip install pytorch-lightning==1.9.0

# %%
import wandb
wandb.login()

# %%
# !python train_VarNet.py
